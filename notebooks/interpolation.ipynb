# %%
import numpy as np
import interpolation as intp
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1, 1)
y = intp.lagrange_polynomial(degree=2, eval_pts=x)
plt.plot(x, y[0])
plt.plot(x, y[1])
plt.plot(x, y[2])
plt.show()
